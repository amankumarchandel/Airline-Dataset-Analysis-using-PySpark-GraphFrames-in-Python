# %% [markdown]
# # <font color=blue><center>Flight Performance Analysis</center></font>

# %% [markdown]
# ## Agenda
#
# ### Use Case
# In this use case, we will use GraphFrames within Databricks notebooks to quickly and easily analyze flight performance data organized in graph structures. Because we’re using graph structures, we can easily ask a number of questions that are not as intuitive as tabular structures such as finding structural motifs, airport ranking using PageRank, and shortest paths between cities.
#
# ### Architecture
# - Overview
# - Tech Stack
#
# ### Environment Setup
# - Databricks Community Edition Registration https://databricks.com/try-databricks?itm_data=NavBar-TryDatabricks-Trial
# - Graphframes Installation
#
# ### Databricks
# - Introduction
# - Getting to know the platform
# - Cluster architecture, workers, drivers and jobs
# - Cluster Creation
# - Importing and storing data
# - dbutils
# - Spark UI, Event Logs, Driver logs and Metrics
#
# ### GraphFrames
# - Graph Analysis
# - Getting started
# - Directed vs undirected edges
# - Filtering and connected components
# - Motif finding
# - TriangleCount and PageRank
#
# ### Data Preparation
# - Raw Layer
# - Landing Layer
# - Building the Graph
#
# ### Data Analysis & Visualization
# - Basic Queries
# - Relationships through Motif Finding
# - Airport Ranking using PageRank
# - Most popular flights
# - Top Transfer Cities
# - Breadth First Search

# %% [markdown]
# ## <font color=blue>Architecture</font>
# ### Overview
# #### Data Flow Architecture
# <img src="https://drive.google.com/uc?export=view&id=1zhoHFsaiBeGF3FXy3oiznaPjk6uvX3T4">
#
# ### Tech Stack
# * <a href = "https://community.cloud.databricks.com/" >Databricks </a>
# * Spark SQL
# * Spark Graphframes

# %% [markdown]
# ## Environment Setup
# - <a href="https://databricks.com/try-databricks?itm_data=NavBar-TryDatabricks-Trial">Databricks Community Edition Registration</a>
# - <a href="https://docs.databricks.com/getting-started/try-databricks.html">Signup guide</a>
# - Graphframes Installation

# %% [markdown]
# ## Databricks
# - Introduction
#  - large scale data processing for batch loads and streaming data
#  - simplifies and accelerates collaborative work among data scientists, data engineers and machine learning engineers
#  - offers complete analytics and machine learning algorithms and languages
#  - features complete ML DevOps model life-cycle; from experimentation to production
#  - is build on Apache Spark and embraces Delta Lake and ML Flow
# - Getting to know the platform
# - Cluster architecture, workers, drivers and jobs
# <img src="https://tomaztsql.files.wordpress.com/2020/12/screenshot-2020-12-05-at-09.36.21.png">
#
# <img src="https://tomaztsql.files.wordpress.com/2020/12/screenshot-2020-12-05-at-09.50.41.png">
#
# <p style="font-size:10px"><figcaption>Taken from <cite><a href="https://tomaztsql.files.wordpress.com">Tomaztsql</a></cite></figcaption></p>
#
# - Cluster Creation
# <br/><img src="https://drive.google.com/uc?export=view&id=1xFwGZ_KLh3mr1I1tXG641IwgXZE0XrYZ">
#
# - Importing and storing data
# - dbutils
# - Spark UI, Event Logs, Driver logs and Metrics

# %% [markdown]
# ## GraphFrames
# - Graph Analysis
#  - method used in computational biology
#  - prominent data analysis technique for both social network analysis and recommender systems
#  - Facebook friend cluster maps is a simple and intuitive example
# - Getting started
#  - GraphFrame is always created from a vertex and an edges DataFrame
#  - Rules creating a GraphFrame
#    - Vertex DataFrame must contain a column named id
#    - Edges DataFrame must contain a column named src
# - Directed vs undirected edges
#  - Directed graphs have edges with no direction
#  - Undirected graphs have edges with no direction
# - Filtering and connected components
# - Motif finding
#  - Useful to discover structural patterns in graphs
#  - find-function is the key to invoke the query
#  - <a href="https://graphframes.github.io/graphframes/docs/_site/user-guide.html#motif-finding">Documentation</a>
# - TriangleCount and PageRank Algorithms
#  - TriangleCount
#    - number of triangles passing through each vertex
#    - triangle can be defined as a group of three vertices that is interrelated
#  - PageRank
#    - Initially used to know how important a website is

# %% [markdown]
# ## Data Preparation
# - Raw Layer
# - Landing Layer
# - Building the Graph

# %% [markdown]
# ## <font color=blue>Data Analysis & Visualization</font>
# - Basic Queries
#  - Determine the number of airports and trips
#  - Determining the longest delay in this dataset
#  - Determining the number of delayed vs. on-time / early flights
#  - What flights departing SFO are most likely to have significant delays
#  - What destinations tend to have delays
#  - What destinations tend to have significant delays departing from SEA
#  - Vertex Degrees
# - Relationships through Motif Finding
# - Airport Ranking using PageRank
# - Most popular flights
# - Top Transfer Cities
# - Breadth First Search

# %% [markdown]
# ## <font color=blue>Project Overview</font>
